# %%
import mean_var_std
#test value one 
test_lst = [0,1,2,3,4,5,6,7,8]
print("Result of test list one")
test_one = mean_var_std.calculate(test_lst)
print(test_one )


print("--------------------------------------------------------------")


#test value two 
test_2nd = [2,6,2,8,4,0,1,5,7]
print("Result of test list two")
test_two = mean_var_std.calculate(test_2nd)
print(test_two)

print("--------------------------------------------------------------")


#test value three 
test_3rd = [9,1,5,3,3,3,2,9,0]
print("Result of test list three")
test_three = mean_var_std.calculate(test_3rd)
print(test_three)


print("--------------------------------------------------------------")
# Out:
# Result of test list one
# {'mean': [[3.0, 4.0, 5.0], [1.0, 4.0, 7.0], 4.0], 'variance': [[6.0, 6.0, 6.0], [0.6666666666666666, 0.6666666666666666, 0.6666666666666666], 6.666666666666667], 'standard deviation': [[2.449489742783178, 2.449489742783178, 2.449489742783178], [0.816496580927726, 0.816496580927726, 0.816496580927726], 2.581988897471611], 'max': [[6, 7, 8], [2, 5, 8], 8], 'min': [[0, 1, 2], [0, 3, 6], 0], 'sum': [[9, 12, 15], [3, 12, 21], 36]}
# --------------------------------------------------------------
# Result of test list two
# ...
